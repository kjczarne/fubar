# %% [markdown]
# # Classifier ROC curve

# %%
import numpy as np

# %%
from sklearn.metrics import auc

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
fpr = np.loadtxt('fpr_1.txt')
tpr = np.loadtxt('tpr_1.txt')

# %%
plt.plot(fpr, tpr)
plt.xlabel("False positive rate")
plt.ylabel("True positive rate")
plt.title("ROC Curve for Inception V3 classifier")
# Out:
# Text(0.5, 1.0, 'ROC Curve for Inception V3 classifier')

# %%
auc(fpr, tpr)
# Out:
# 0.7788323659952201

# %% [markdown]
# ## After manual filtering:

# %%
fpr = np.loadtxt('fpr_2.txt')
tpr = np.loadtxt('tpr_2.txt')

# %%
plt.plot(fpr, tpr)
plt.xlabel("False positive rate")
plt.ylabel("True positive rate")
plt.title("ROC Curve for Inception V3 classifier")
# Out:
# Text(0.5, 1.0, 'ROC Curve for Inception V3 classifier')

# %%
auc(fpr, tpr)
# Out:
# 0.8994220354053835
